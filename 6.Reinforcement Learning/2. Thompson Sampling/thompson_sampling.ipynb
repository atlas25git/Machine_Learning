# %% [markdown]
# # Thompson Sampling

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Ads_CTR_Optimisation.csv')

# %% [markdown]
# ## Implementing Thompson Sampling

# %%
import random
reward1 = [0]*10
reward0 = [0]*10
ads_selected = []
for i in range (0,500):
  ad = 0;
  max_random = 0;
  for j in range (0,10):
    random_b = random.betavariate(reward1[j]+1,reward0[j]+1)
    if(random_b>max_random):
      max_random = random_b
      ad = j
  ads_selected.append(ad)
  if(dataset.values[i][ad] == 0):
    reward0[ad]=reward0[ad]+1
  if(dataset.values[i][ad] == 1):
    reward1[ad]=reward1[ad]+1

# %% [markdown]
# ## Visualising the results - Histogram

# %%
plt.hist(ads_selected)
plt.title('Histogram of ads selections')
plt.xlabel('Ads')
plt.ylabel('Number of times each ad was selected')
plt.show()
